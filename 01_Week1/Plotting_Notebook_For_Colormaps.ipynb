# %%
import numpy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = np.array( [
    [1,2],
    [3,4],
    [4,5],
] )

# %%
column1 = numpy.random.uniform(0, 1, 10)
print( column1 )
column2 = numpy.random.uniform(0, 1, 10)
print( column2 )

dataset2 = numpy.vstack([column1, column2]).T
print(dataset2)
# Out:
# [0.74887728 0.12881615 0.30686526 0.05902456 0.55380421 0.27398403
#  0.07733592 0.6622391  0.24246485 0.74160124]
# [0.9418101  0.4914325  0.16257944 0.59812293 0.34629066 0.10820741
#  0.1204924  0.8051461  0.16746815 0.22407902]
# [[0.74887728 0.9418101 ]
#  [0.12881615 0.4914325 ]
#  [0.30686526 0.16257944]
#  [0.05902456 0.59812293]
#  [0.55380421 0.34629066]
#  [0.27398403 0.10820741]
#  [0.07733592 0.1204924 ]
#  [0.6622391  0.8051461 ]
#  [0.24246485 0.16746815]
#  [0.74160124 0.22407902]]

# %%
zerothrow = dataset2[0]
print(zerothrow)
# Out:
# [0.74887728 0.9418101 ]

# %%
singleelement = dataset2[1][1]
print(singleelement)
# Out:
# 0.49143250302139174

# %%
plt.scatter( dataset2[:, 0], dataset2[:, 1])

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)] #<-------------- skip explaining this
data = np.random.multivariate_normal(mean, cov, 2000) #,------ skip explaining


df = pd.DataFrame(data, columns=["x", "y"])
print('df', df)
# Out:
# df              x         y
# 0    -1.723756 -0.661334
# 1    -0.271764 -0.011374
# 2    -2.160843  1.763510
# 3    -0.221132  1.813835
# 4    -0.226711 -0.004262
# ...        ...       ...
# 1995  0.016308  2.015567
# 1996 -0.836787 -1.226981
# 1997 -0.174143  1.169164
# 1998 -2.000879  1.296752
# 1999  0.049401  1.320433
#
# [2000 rows x 2 columns]

# %%
fig, ax = plt.subplots()

axesobject = ax.hist2d(df.x,df.y, bins=30)
plt.xlabel('this is some label')
plt.ylabel('this is y label')
plt.scatter( df.x , df.y, alpha = .5, color = 'red', s=1)
plt.colorbar( axesobject[3] )

# %%
a = """
fig, ax = plt.subplots()
#axesobject = ax.hist2d(df.x,df.y, bins=30)
plt.xlabel('this is some label')
plt.ylabel('this is y label')
#fig.colorbar(h[3], ax=ax)
plt.plot( df.x, df.y, alpha = .5, color = 'red', ms=10, linestyle = '.')
#plt.colorbar( axesobject[3] )

"""
#Take away: sometimes very simliar functions 

#exist to do the same thing with slightly different behavior

# %%
#https://stackoverflow.com/questions/16150819/common-xlabel-ylabel-for-matplotlib-subplots
fig, ax = plt.subplots(1, 2)

axesobject = ax[0].hist2d(df.x,df.y, bins=30)
fig.text(0.5, 0.04, ' common X', ha='center')
ax[0].set_xlabel('\nx1 label')
ax[1].set_xlabel('$x2=\int_{-1}^{1}$ label')

ax[0].set_ylabel('this is y label')
ax[1].scatter( df.x , df.y, alpha = .5, color = 'red', s=1)
plt.colorbar( axesobject[3] )
